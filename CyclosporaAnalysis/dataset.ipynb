# %%
# Imports
import pandas as pd
import numpy as np

# %%
## Taylor Farms regional distribution centers
df = pd.DataFrame({
    "Location": [
        "Guanajuato",               # Taylor Farms Mexico — Guanajuato, Mexico
        "Salinas, CA",              # Taylor Farms Retail — 150 Main St Ste 300, Salinas, CA 93901
        "Salinas, CA",              # Taylor Farms California — 1207 Abbott St, Salinas, CA 93902
        "Colorado Springs, CO",     # Taylor Farms Colorado — 890 N Newport Rd, Colorado Springs, CO 80916
        "Annapolis Junction, MD",   # Taylor Farms Maryland — 9055 Junction Dr, Annapolis Junction, MD 20701
    ],
    "latitude": [21.019, 36.6706, 36.6790, 38.8260, 39.1067],
    "longitude": [-101.253, -121.6553, -121.6420, -104.7030, -76.7885],
    "Distribution Facility": [
        "Taylor Farms Mexico",
        "Taylor Farms Retail",
        "Taylor Farms California",
        "Taylor Farms Colorado",
        "Taylor Farms Maryland",
    ],
})

# Print sample
df.head()
# Out:
#                  Location  latitude  longitude    Distribution Facility
# 0              Guanajuato   21.0190  -101.2530      Taylor Farms Mexico
# 1             Salinas, CA   36.6706  -121.6553      Taylor Farms Retail
# 2             Salinas, CA   36.6790  -121.6420  Taylor Farms California
# 3    Colorado Springs, CO   38.8260  -104.7030    Taylor Farms Colorado
# 4  Annapolis Junction, MD   39.1067   -76.7885    Taylor Farms Maryland

# %%
## Recall States
df_recall_states = pd.DataFrame({
    "State": [
        "New Hampshire",
        "New Jersey",
        "Massachusetts",
        "Connecticut",
        "California",
        "Colorado",
        "Maryland",
        "Pennsylvania",
        "Michigan",
        "Ohio",
        "Virginia",
        "North Carolina",
        "South Carolina",
        "Georgia",
        "Florida",
        "Alabama",
        "Texas",
        "Oklahoma",
        "Louisiana",
        "Mississippi",
        "Kansas",
        "Arkansas",
        "Tennessee",
        "Iowa",
        "Illinois"
    ],
    "Abbreviation": [
        "NH",
        "NJ",
        "MA",
        "CT",
        "CA",
        "CO",
        "MD",
        "PA",
        "MI",
        "OH",
        "VA",
        "NC",
        "SC",
        "GA",
        "FL",
        "AL",
        "TX",
        "OK",
        "LA",
        "MS",
        "KS",
        "AR",
        "TN",
        "IA",
        "IL"
    ],
})

# Print sample
df_recall_states.head()
